# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/binh.le/Documents/accepted_2007_to_2018Q4.csv")
print(data.shape)
# Out:
# /var/folders/2q/zd48l6zs0t7f59km0d3kbtp80000gp/T/ipykernel_47913/101748923.py:1: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/binh.le/Documents/accepted_2007_to_2018Q4.csv")
# (2260701, 151)

# %%
data.sample(10000, random_state=42).to_csv("/Users/binh.le/Documents/accepted_2007_to_2018Q4_sample.csv", index=False)

# %%
data
# Out:
#                                                        id  member_id  \
# 0                                                68407277        NaN
# 1                                                68355089        NaN
# 2                                                68341763        NaN
# 3                                                66310712        NaN
# 4                                                68476807        NaN
# ...                                                   ...        ...
# 2260696                                          88985880        NaN
# 2260697                                          88224441        NaN
# 2260698                                          88215728        NaN
# 2260699  Total amount funded in policy code 1: 1465324575        NaN
# 2260700   Total amount funded in policy code 2: 521953170        NaN
#
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# ...
